# %% [markdown]
# # Big Data Storage and Management (CDS502)
# # Introduction to Pandas (Part 1)
# ### by Dr. Chew XinYing

# %% [markdown]
# ### Pandas DataFrame

# %% [markdown]
# What is a DataFrame?
#
# * 2-dimensional labled tabular data (think spreadsheet or SQL table)
# * **heterogeneous** data, composed of multiple **Series**
# * an **Index** or "row label" for selection operations

# %%
# !conda install pandas=0.16.0
import pandas as pd

# %% [markdown]
# ### Creating a DataFrame

# %%
cd C:/Users/USER/Desktop
# Out:
# C:\Users\USER\Desktop

# %%
# Creating a DataFrame from a file read:

file    = "exoplanets.csv"
df_file = pd.read_csv(file)
df_file
pd.read_csv("exoplanets.csv")
# Out:
#                   NAME                    FIRSTREF  \
# 0          gamma Cep b               Campbell 1988
# 1          HD 114762 b                 Latham 1989
# 2       PSR B1257+12 B              Wolszczan 1992
# 3       PSR B1257+12 A              Wolszczan 1992
# 4           beta Gem b                 Hatzes 1993
# 5       PSR B1257+12 C              Wolszczan 1994
# 6             51 Peg b                  Mayor 1995
# 7             47 UMa b                 Butler 1996
# 8             70 Vir b                  Marcy 1996
# 9           16 Cyg B b                Cochran 1997
# 10           tau Boo b                 Butler 1997
# 11           rho CrB b                  Noyes 1997
# 12            55 Cnc b                 Butler 1997
# 13       upsilon And b                 Butler 1997
# 14         HD 187123 b                 Butler 1998
# 15            GJ 876 b  Delfosse 1998 ; Marcy 1998
# 16       upsilon And c                 Butler 1999
# ...

# %%
# To list out all columns' name of the dataframe

print(df_file.columns)
# Out:
# Index(['NAME', 'FIRSTREF', 'FIRSTURL', 'DATE', 'NUM_OBS', 'MASS(mjupiter)',
#        'RADIUS(rjupiter)', 'PERIOD(day)', 'ECCENTRICITY',
#        'SEMI_MAJOR_AXIS(AU)', 'SEPARATION(AU)', 'STAR_NAME', 'DIST(PARSEC)',
#        'RA_STRING(h:m:s)', 'DEC_STRING(d:m:s)', 'STAR_MASS(msun)',
#        'STAR_RADIUS(rsun)'],
#       dtype='object')

# %%
# Time taken to read csv file into pandas dataframe
import pandas as pd
import timeit
file = pd.read_csv("Iris.csv")
TestKN_StartTime = timeit.default_timer()
file = pd.read_csv("Iris.csv")
TestKN_ElapsedTime = timeit.default_timer() - TestKN_StartTime
print ("Elapsed Time (Seconds):",TestKN_ElapsedTime)
file
# Out:
# Elapsed Time (Seconds): 0.004890455419927646
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# ...

# %%
df3=pd.read_csv("crimes.csv",nrows=99)
df3
# Out:
#          ID Case Number                    Date                      Block  \
# 0   3753774    HK769786  11/23/2004 10:15:00 PM           029XX S STATE ST
# 1   3753775    HL121290  01/12/2005 08:15:00 PM           111XX S STATE ST
# 2   3753776    HL122737  01/13/2005 02:45:00 PM         104XX S WALLACE ST
# 3   3753777    HL121030  01/12/2005 05:35:00 PM         037XX W ALTGELD ST
# 4   3753781    HK756758  11/17/2004 04:45:00 PM         002XX S ALBANY AVE
# 5   3753784    HK774022  11/26/2004 02:45:00 PM            015XX W 13TH ST
# 6   3753785    HL120239  01/12/2005 09:30:00 AM            023XX W 71ST ST
# 7   3753786    HL122544  01/12/2005 01:27:00 PM           011XX N CLARK ST
# 8   3753787    HL121369  01/12/2005 07:30:00 PM            004XX E 79TH ST
# 9   3753789    HL123269  01/13/2005 07:05:00 PM         126XX S HALSTED ST
# 10  3753790    HL121726  01/13/2005 01:15:00 AM        029XX S DEARBORN ST
# ...

# %%
df4=pd.read_csv("crimes.csv", skiprows=range(1, 10000), nrows=99)
df4
# Out:
#          ID Case Number                    Date                      Block  \
# 0   3768180    HK762414  11/20/2004 10:08:00 AM            005XX E 36TH ST
# 1   3768181    HL126712  01/15/2005 06:15:00 PM    019XX W WASHINGTON BLVD
# 2   3768182    HL137245  01/21/2005 05:00:00 PM            016XX E 79TH ST
# 3   3768183    HL139751  01/23/2005 12:00:00 PM    021XX W WASHINGTON BLVD
# 4   3768184    HK762413  11/20/2004 10:05:00 AM            005XX E 36TH ST
# 5   3768185    HK795195  12/07/2004 01:50:00 PM     015XX N LEAMINGTON AVE
# 6   3768187    HL136522  01/21/2005 08:30:00 AM          004XX W DEMING PL
# 7   3768188    HK762530  11/20/2004 09:00:00 AM      046XX S WASHTENAW AVE
# 8   3768189    HL134286  01/18/2005 12:00:00 PM            018XX W IOWA ST
# 9   3768190    HK795409  12/07/2004 04:34:21 PM         111XX S NORMAL AVE
# 10  3768191    HL140515  01/23/2005 06:30:00 PM          016XX N LOREL AVE
# ...
